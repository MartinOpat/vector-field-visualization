# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Define grid size
n = 20  # Number of points in x and y
x = np.linspace(-10, 10, n)
y = np.linspace(-10, 10, n)

# Create a meshgrid
X, Y = np.meshgrid(x, y)

# Define the radial vector field
U = X  # X-component of the vector field
V = Y  # Y-component of the vector 

# Normalize the vector field
magnitude = np.sqrt(U**2 + V**2)
U_normalized = U / (magnitude + 1e-5)
V_normalized = V / (magnitude + 1e-5)

# Plot the vector field
plt.figure()
plt.quiver(X, Y, U_normalized, V_normalized, magnitude, cmap='viridis')
plt.title('Radial Vector Field')
plt.colorbar(label='Magnitude')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
# Define the circular/swirl vector field
U = -Y  # X-component of the vector field (rotation)
V = X   # Y-component of the vector field (rotation)

# Normalize the vector field
magnitude = np.sqrt(U**2 + V**2)
U_normalized = U / (magnitude + 1e-5)
V_normalized = V / (magnitude + 1e-5)

# Plot the vector field
plt.figure()
plt.quiver(X, Y, U_normalized, V_normalized, magnitude, cmap='plasma')
plt.title('Swirling Flow Field')
plt.colorbar(label='Magnitude')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
# Define the linear vector field with gradients
U = np.ones_like(X)  # Constant x-component (linear flow)
V = np.zeros_like(Y)  # No vertical component

# Create a gradient for the magnitude
magnitude = X + 10  # Magnitude increases from left to right

# Plot the vector field
plt.figure()
plt.quiver(X, Y, U, V, magnitude, cmap='cool')
plt.title('Linear Flow with Gradient')
plt.colorbar(label='Magnitude')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
# Define the turbulent (chaotic) vector field
U = np.random.randn(n, n)  # Random x-component of the vector field
V = np.random.randn(n, n)  # Random y-component of the vector field

# Calculate the magnitude of the vectors
magnitude = np.sqrt(U**2 + V**2)

# Plot the vector field
plt.figure()
plt.quiver(X, Y, U, V, magnitude, cmap='inferno')
plt.title('Turbulent Flow Field')
plt.colorbar(label='Magnitude')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %% [markdown]
# # 3D

# %%
# Define grid size
n = 10  # Number of points in each axis
x = np.linspace(-5, 5, n)
y = np.linspace(-5, 5, n)
z = np.linspace(-5, 5, n)

# Create a 3D meshgrid
X, Y, Z = np.meshgrid(x, y, z)

# Define the radial vector field in 3D
U = X  # X-component of the vector field
V = Y  # Y-component of the vector field
W = Z  # Z-component of the vector field

# Normalize the vector field (optional)
magnitude = np.sqrt(U**2 + V**2 + W**2)
U_normalized = U / (magnitude + 1e-5)
V_normalized = V / (magnitude + 1e-5)
W_normalized = W / (magnitude + 1e-5)

# Plot the vector field using quiver3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.quiver(X, Y, Z, U_normalized, V_normalized, W_normalized, length=0.5, color='b')
ax.set_title('Radial Vector Field (3D)')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
plt.show()

# %%
# Define the swirling vector field in 3D
U = -Y  # X-component of the vector field
V = X   # Y-component of the vector field
W = np.zeros_like(Z)  # No movement in the Z direction

# Normalize the vector field (optional)
magnitude = np.sqrt(U**2 + V**2 + W**2)
U_normalized = U / (magnitude + 1e-5)
V_normalized = V / (magnitude + 1e-5)
W_normalized = W / (magnitude + 1e-5)

# Plot the vector field using quiver3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.quiver(X, Y, Z, U_normalized, V_normalized, W_normalized, length=0.5, color='r')
ax.set_title('Swirling Flow Field (3D)')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
plt.show()

# %%
# Define the linear vector field in 3D with gradient
U = np.ones_like(X)  # Constant x-component (linear flow)
V = np.zeros_like(Y)  # No movement in Y direction
W = np.zeros_like(Z)  # No movement in Z direction

# Create a gradient for the magnitude
magnitude = X + 5  # Magnitude increases from left to right

# Plot the vector field using quiver3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.quiver(X, Y, Z, U, V, W, length=0.5, color='g')
ax.set_title('Linear Flow with Gradient (3D)')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
plt.show()

# %%
# Define the turbulent (chaotic) vector field in 3D
U = np.random.randn(n, n, n)  # Random x-component of the vector field
V = np.random.randn(n, n, n)  # Random y-component of the vector field
W = np.random.randn(n, n, n)  # Random z-component of the vector field

# Calculate the magnitude of the vectors
magnitude = np.sqrt(U**2 + V**2 + W**2)

# Plot the vector field using quiver3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.quiver(X, Y, Z, U, V, W, length=0.5, color='m')
ax.set_title('Turbulent Flow Field (3D)')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
plt.show()

# %% [markdown]
# # Interactive

# %%
import plotly.graph_objects as go

# %%
# Define grid size
n = 10  # Number of points in each axis
x = np.linspace(-5, 5, n)
y = np.linspace(-5, 5, n)
z = np.linspace(-5, 5, n)

# Create a 3D meshgrid
X, Y, Z = np.meshgrid(x, y, z)

# Define the radial vector field in 3D
U = X  # X-component of the vector field
V = Y  # Y-component of the vector field
W = Z  # Z-component of the vector field

# Normalize the vector field (optional)
magnitude = np.sqrt(U**2 + V**2 + W**2)
U_normalized = U / (magnitude + 1e-5)
V_normalized = V / (magnitude + 1e-5)
W_normalized = W / (magnitude + 1e-5)

# Create 3D quiver plot
fig = go.Figure(data=go.Cone(
    x=X.flatten(),
    y=Y.flatten(),
    z=Z.flatten(),
    u=U_normalized.flatten(),
    v=V_normalized.flatten(),
    w=W_normalized.flatten(),
    colorscale='Blues',
    sizemode="absolute",
    sizeref=0.2,  # Scaling factor
    showscale=True))

# Customize layout
fig.update_layout(
    scene=dict(
        xaxis_title='X-axis',
        yaxis_title='Y-axis',
        zaxis_title='Z-axis'
    ),
    title="Interactive Radial Vector Field (3D)"
)

# Show interactive plot
fig.show()

# %%
import ipywidgets as widgets
from IPython.display import display

# %%
# Create a radial vector field in 3D
def generate_radial_vector_field(n):
    x = np.linspace(-5, 5, n)
    y = np.linspace(-5, 5, n)
    z = np.linspace(-5, 5, n)
    X, Y, Z = np.meshgrid(x, y, z)
    
    U = X  # X-component of the vector field
    V = Y  # Y-component of the vector field
    W = Z  # Z-component of the vector field
    
    magnitude = np.sqrt(U**2 + V**2 + W**2)
    U_normalized = U / (magnitude + 1e-5)
    V_normalized = V / (magnitude + 1e-5)
    W_normalized = W / (magnitude + 1e-5)
    
    return X, Y, Z, U_normalized, V_normalized, W_normalized

# Plot the 3D vector field
def plot_vector_field(scale, angle):
    X, Y, Z, U, V, W = generate_radial_vector_field(10)
    
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    # Apply scaling
    ax.quiver(X, Y, Z, U, V, W, length=scale, color='b')
    
    # Rotate the plot by the given angle
    ax.view_init(30, angle)
    
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_zlabel('Z-axis')
    plt.title('Interactive Radial Vector Field (3D)')
    plt.show()

# Create sliders for interactivity
scale_slider = widgets.FloatSlider(min=0.1, max=2.0, step=0.1, value=0.5, description='Scale')
angle_slider = widgets.FloatSlider(min=0, max=360, step=1, value=30, description='Rotation Angle')

# Connect the sliders to the plot function
widgets.interact(plot_vector_field, scale=scale_slider, angle=angle_slider)

display(scale_slider, angle_slider)
# Out:
# interactive(children=(FloatSlider(value=0.5, description='Scale', max=2.0, min=0.1), FloatSlider(value=30.0, d…
# FloatSlider(value=0.5, description='Scale', max=2.0, min=0.1)
# FloatSlider(value=30.0, description='Rotation Angle', max=360.0, step=1.0)

# %% [markdown]
# # Color maps

# %%
# Heatmap of the uniform 3d vector field
n = 10  # Number of points in each axis
x = np.linspace(-5, 5, n)
y = np.linspace(-5, 5, n)
z = np.linspace(-5, 5, n)

# Create a 3D meshgrid
X, Y, Z = np.meshgrid(x, y, z)

# Define the uniform vector field in 3D
U = np.ones_like(X)  # Constant x-component

# Create a 3D heatmap
fig = go.Figure(data=go.Volume(
    x=X.flatten(),
    y=Y.flatten(),
    z=Z.flatten(),
    value=U.flatten(),
    isomin=-1,
    isomax=1,
    opacity=0.1,  # Transparency
    surface_count=21,  # Number of isosurfaces
    colorscale='Viridis'
))

# Customize layout
fig.update_layout(
    scene=dict(
        xaxis_title='X-axis',
        yaxis_title='Y-axis',
        zaxis_title='Z-axis'
    ),
    title="Uniform 3D Vector Field"
)

# Show interactive plot
fig.show()

# %%
# Use matplotlib to plot the uniform 3d vector field using heatmap
n = 50  # Increase the number of points in each axis for a more continuous appearance
x = np.linspace(-5, 5, n)
y = np.linspace(-5, 5, n)
z = np.linspace(-5, 5, n)

# Create a 3D meshgrid
X, Y, Z = np.meshgrid(x, y, z, indexing='ij')

# Define the uniform vector field in 3D
U = np.ones_like(X)  # Constant x-component

# Flatten the arrays for scatter plot
X_flat = X.flatten()
Y_flat = Y.flatten()
Z_flat = Z.flatten()
U_flat = U.flatten()

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create a 3D heatmap using scatter plot with decreased opacity
sc = ax.scatter(X_flat, Y_flat, Z_flat, c=U_flat, cmap='viridis', alpha=0.1)

# Add color bar to show the intensity scale
plt.colorbar(sc)

# Customize plot
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
plt.title('Uniform 3D Vector Field Heatmap')
plt.show()

# %%
# Heatmap of the radial 3d vector field
n = 10  # Number of points in each axis
x = np.linspace(-5, 5, n)
y = np.linspace(-5, 5, n)
z = np.linspace(-5, 5, n)

# Create a 3D meshgrid
X, Y, Z = np.meshgrid(x, y, z)

# Define the radial vector field in 3D
U = X  # X-component of the vector field

# Create a 3D heatmap
fig = go.Figure(data=go.Volume(
    x=X.flatten(),
    y=Y.flatten(),
    z=Z.flatten(),
    value=U.flatten(),
    isomin=-5,
    isomax=5,
    opacity=0.1,  # Transparency
    surface_count=21,  # Number of isosurfaces
    colorscale='Viridis'
))

# Customize layout
fig.update_layout(
    scene=dict(
        xaxis_title='X-axis',
        yaxis_title='Y-axis',
        zaxis_title='Z-axis'
    ),
    title="Radial 3D Vector Field"
)

# Show interactive plot
fig.show()

# %%
# Heatmap of the radial 3d vector field using matplotlib
n = 50  # Increase the number of points in each axis for a more continuous appearance
x = np.linspace(-5, 5, n)
y = np.linspace(-5, 5, n)
z = np.linspace(-5, 5, n)

# Create a 3D meshgrid
X, Y, Z = np.meshgrid(x, y, z, indexing='ij')

# Define the radial vector field in 3D
U = X  # X-component of the vector field
V = Y  # Y-component of the vector field
W = Z  # Z-component of the vector field

# Compute the magnitude of the vector field for color mapping
magnitude = np.sqrt(U**2 + V**2 + W**2)

# Flatten the arrays for scatter plot
X_flat = X.flatten()
Y_flat = Y.flatten()
Z_flat = Z.flatten()
magnitude_flat = magnitude.flatten()

# Create a figure and a 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create a 3D heatmap using scatter plot with decreased opacity
sc = ax.scatter(X_flat, Y_flat, Z_flat, c=magnitude_flat, cmap='viridis', alpha=1)

# Add color bar to show the intensity scale
plt.colorbar(sc)

# Set the axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set the title of the plot
plt.title('Radial 3D Vector Field Heatmap')

# Show the plot
plt.show()

# %%
# Heatmap of the swirling 3d vector field
n = 10  # Number of points in each axis
x = np.linspace(-5, 5, n)
y = np.linspace(-5, 5, n)
z = np.linspace(-5, 5, n)

# Create a 3D meshgrid
X, Y, Z = np.meshgrid(x, y, z)

# Define the swirling vector field in 3D
U = -Y  # X-component of the vector field
V = X   # Y-component of the vector field
W = Z   # Z-component of the vector field

# Create a 3D heatmap
fig = go.Figure(data=go.Volume(
    x=X.flatten(),
    y=Y.flatten(),
    z=Z.flatten(),
    value=U.flatten(),
    isomin=-5,
    isomax=5,
    opacity=0.1,  # needs to be small to see through all surfaces
    surface_count=17,  # needs to be a large number for good volume rendering
    colorscale='RdBu',
    colorbar=dict(thickness=20, ticklen=4)
))

fig.update_layout(scene_xaxis_showspikes=False,
                  scene_yaxis_showspikes=False,
                  scene_zaxis_showspikes=False)
fig.show()

# %%
# Heatmap of the swirling 3d vector field using matplotlib
n = 50  # Increase the number of points in each axis for a more continuous appearance
x = np.linspace(-5, 5, n)
y = np.linspace(-5, 5, n)
z = np.linspace(-5, 5, n)

# Create a 3D meshgrid
X, Y, Z = np.meshgrid(x, y, z, indexing='ij')

# Define the swirling vector field in 3D
U = -Y  # X-component of the vector field
V = X   # Y-component of the vector field
W = np.zeros_like(Z)  # Z-component of the vector field (no vertical component)

# Compute the magnitude of the vector field for color mapping
magnitude = np.sqrt(U**2 + V**2 + W**2)

# Flatten the arrays for scatter plot
X_flat = X.flatten()
Y_flat = Y.flatten()
Z_flat = Z.flatten()
magnitude_flat = magnitude.flatten()

# Create a figure and a 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create a 3D heatmap using scatter plot with decreased opacity
sc = ax.scatter(X_flat, Y_flat, Z_flat, c=magnitude_flat, cmap='viridis', alpha=1)

# Add color bar to show the intensity scale
plt.colorbar(sc)

# Set the axis labels
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Set the title of the plot
plt.title('Swirling 3D Vector Field Heatmap')

# Show the plot
plt.show()

# %%
# Heatmap of the random 3d vector field
n = 10  # Number of points in each axis
x = np.linspace(-5, 5, n)
y = np.linspace(-5, 5, n)
z = np.linspace(-5, 5, n)

# Create a 3D meshgrid
X, Y, Z = np.meshgrid(x, y, z)

# Define the random vector field in 3D
U = np.random.randn(n, n, n)  # Random x-component of the vector field
V = np.random.randn(n, n, n)  # Random y-component of the vector field
W = np.random.randn(n, n, n)  # Random z-component of the vector

# Calculate the magnitude of the vectors
magnitude = np.sqrt(U**2 + V**2 + W**2)

# Create a 3D heatmap
fig = go.Figure(data=go.Volume(
    x=X.flatten(),
    y=Y.flatten(),
    z=Z.flatten(),
    value=magnitude.flatten(),
    isomin=0,
    isomax=5,
    opacity=0.1,  # Transparency
    surface_count=21,  # Number of isosurfaces
    colorscale='Viridis'
))

# Customize layout
fig.update_layout(
    scene=dict(
        xaxis_title='X-axis',
        yaxis_title='Y-axis',
        zaxis_title='Z-axis'
    ),
    title="Random 3D Vector Field"
)

# Show interactive plot
fig.show()

# %%
# Heatmap of the random 3d vector field using matplotlib
n = 50  # Increase the number of points in each axis for a more continuous appearance
x = np.linspace(-5, 5, n)
y = np.linspace(-5, 5, n)
z = np.linspace(-5, 5, n)

# Create a 3D meshgrid
X, Y, Z = np.meshgrid(x, y, z, indexing='ij')

# Define the random vector field in 3D
U = np.random.randn(n, n, n)  # Random x-component of the vector field
V = np.random.randn(n, n, n)  # Random y-component of the vector field
W = np.random.randn(n, n, n)  # Random z-component of the vector field

# Compute the magnitude of the vector field for color mapping
magnitude = np.sqrt(U**2 + V**2 + W**2)

# Flatten the arrays for scatter plot
X_flat = X.flatten()
Y_flat = Y.flatten()
Z_flat = Z.flatten()
magnitude_flat = magnitude.flatten()

# Create a figure and a 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Create a 3D heatmap using scatter plot with decreased opacity
sc = ax.scatter(X_flat, Y_flat, Z_flat, c=magnitude_flat, cmap='viridis', alpha=0.3)

# Add color bar to show the intensity scale
plt.colorbar(sc)

# Set the axis labels
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')

# Set the title of the plot
plt.title('Random 3D Vector Field Heatmap')

# Show the plot
plt.show()

# %% [markdown]
# # DVR

# %%
# THIS IS NOT USEFUL, JUST TESTING
import os
os.environ['ETS_TOOLKIT'] = 'qt'

from mayavi import mlab
import numpy as np

# Define the grid size
n = 10
x = np.linspace(-5, 5, n)
y = np.linspace(-5, 5, n)
z = np.linspace(-5, 5, n)

# Create a 3D meshgrid
X, Y, Z = np.meshgrid(x, y, z)

# Define the uniform vector field in 3D
U = np.ones_like(X)  # Constant x-component
V = np.zeros_like(Y)  # No movement in Y direction
W = np.zeros_like(Z)  # No movement

# Compute the magnitude of the vector field
magnitude = np.sqrt(U**2 + V**2 + W**2)

# Create a figure
mlab.figure(bgcolor=(1, 1, 1), size=(800, 600))

# Use `quiver3d` for 3D vector field
mlab.quiver3d(X, Y, Z, U, V, W, scalars=magnitude, colormap='Blues', scale_factor=0.5)

# Optionally use streamlines for a smoother visualization
# streamlines = mlab.flow(X, Y, Z, U, V, W, seed_scale=0.2)

# Customize view
mlab.axes(xlabel='X', ylabel='Y', zlabel='Z')
mlab.colorbar(title='Vector Magnitude', orientation='vertical')
mlab.title('3D Vector Field with DVR-like Rendering')

# Show the plot
mlab.show()
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in ""

# %%
# DVR for 3d uniform vector field

from mayavi import mlab
import numpy as np

# Define the grid size
n = 50  # Increase the resolution for smoother results
x = np.linspace(-5, 5, n)
y = np.linspace(-5, 5, n)
z = np.linspace(-5, 5, n)

# Create a 3D meshgrid
X, Y, Z = np.meshgrid(x, y, z)

# Define the uniform vector field in 3D
U = np.ones_like(X)  # Constant x-component
V = np.zeros_like(Y)  # No movement in Y direction
W = np.zeros_like(Z)  # No movement

# Calculate the vector field magnitude
magnitude = np.sqrt(U**2 + V**2 + W**2)

# Normalize the magnitude to use it as a density volume for rendering
magnitude = magnitude / np.max(magnitude)

# Create the volume rendering
mlab.figure(bgcolor=(1, 1, 1), size=(800, 600))
src = mlab.pipeline.scalar_field(magnitude)

# Apply volume rendering
vol = mlab.pipeline.volume(src, vmin=0.1, vmax=1.0)

# Customize the visualization (ray-casting like)
mlab.view(azimuth=45, elevation=60, distance=15)
mlab.axes(xlabel='X', ylabel='Y', zlabel='Z')
mlab.colorbar(title='Magnitude', orientation='vertical')

# Show the visualization
mlab.show()
# Out:
# /home/martin/vector-field-visualization/.venv/lib/python3.10/site-packages/mayavi/tools/modules.py:658: RuntimeWarning:
#
# invalid value encountered in scalar divide

# %%
# dvr for 3d radial vector field

from mayavi import mlab
import numpy as np

# Define the grid size
n = 50  # Increase the resolution for smoother results
x = np.linspace(-5, 5, n)
y = np.linspace(-5, 5, n)
z = np.linspace(-5, 5, n)

# Create a 3D meshgrid
X, Y, Z = np.meshgrid(x, y, z)

# Define the radial vector field in 3D
U = X  # X-component of the vector field
V = Y  # Y-component of the vector field
W = Z  # Z

# Calculate the vector field magnitude
magnitude = np.sqrt(U**2 + V**2 + W**2)

# Normalize the magnitude to use it as a density volume for rendering
magnitude = magnitude / np.max(magnitude)

# Create the volume rendering
mlab.figure(bgcolor=(1, 1, 1), size=(800, 600))

# Create a scalar field for the magnitude
src = mlab.pipeline.scalar_field(magnitude)

# Apply volume rendering
vol = mlab.pipeline.volume(src, vmin=0.1, vmax=1.0)

# Customize the visualization (ray-casting like)
mlab.view(azimuth=45, elevation=60, distance=15)

# Add axes and color bar
mlab.axes(xlabel='X', ylabel='Y', zlabel='Z')

# Add a color bar
mlab.colorbar(title='Magnitude', orientation='vertical')

# Show the visualization
mlab.show()

# %%
# dvr for 3d swirling vector field

from mayavi import mlab
import numpy as np

# Define the grid size
n = 50  # Increase the resolution for smoother results
x = np.linspace(-5, 5, n)
y = np.linspace(-5, 5, n)
z = np.linspace(-5, 5, n)

# Create a 3D meshgrid
X, Y, Z = np.meshgrid(x, y, z)

# Define the swirling vector field in 3D
U = -Y  # X-component of the vector field
V = X   # Y-component of the vector field
W = np.zeros_like(Z)  # Z-component of the vector field (no vertical component)

# Calculate the vector field magnitude
magnitude = np.sqrt(U**2 + V**2 + W**2)

# Normalize the magnitude to use it as a density volume for rendering
magnitude = magnitude / np.max(magnitude)

# Create the volume rendering
mlab.figure(bgcolor=(1, 1, 1), size=(800, 600))

# Create a scalar field for the magnitude
src = mlab.pipeline.scalar_field(magnitude)

# Apply volume rendering
vol = mlab.pipeline.volume(src, vmin=0.1, vmax=1.0)

# Customize the visualization (ray-casting like)
mlab.view(azimuth=45, elevation=60, distance=15)

# Add axes and color bar
mlab.axes(xlabel='X', ylabel='Y', zlabel='Z')

# Add a color bar
mlab.colorbar(title='Magnitude', orientation='vertical')

# Show the visualization
mlab.show()

# %%
# dvr for 3d random vector field

from mayavi import mlab
import numpy

# Define the grid size
n = 50  # Increase the resolution for smoother results
x = numpy.linspace(-5, 5, n)
y = numpy.linspace(-5, 5, n)
z = numpy.linspace(-5, 5, n)

# Create a 3D meshgrid
X, Y, Z = numpy.meshgrid(x, y, z)

# Define the random vector field in 3D

U = numpy.random.randn(n, n, n)  # Random x-component of the vector field
V = numpy.random.randn(n, n, n)  # Random y-component of the vector field
W = numpy.random.randn(n, n, n)  # Random z-component of the vector

# Calculate the vector field magnitude
magnitude = numpy.sqrt(U**2 + V**2 + W**2)

# Normalize the magnitude to use it as a density volume for rendering
magnitude = magnitude / numpy.max(magnitude)

# Create the volume rendering
mlab.figure(bgcolor=(1, 1, 1), size=(800, 600))

# Create a scalar field for the magnitude
src = mlab.pipeline.scalar_field(magnitude)

# Apply volume rendering
vol = mlab.pipeline.volume(src, vmin=0.1, vmax=1.0)

# Customize the visualization (ray-casting like)
mlab.view(azimuth=45, elevation=60, distance=15)

# Add axes and color bar
mlab.axes(xlabel='X', ylabel='Y', zlabel='Z')

# Add a color bar
mlab.colorbar(title='Magnitude', orientation='vertical')

# Show the visualization
mlab.show()

# %% [markdown]
# # streamlines

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.integrate import odeint

# Define the vector field (back to a uniform field, simplified)
def vector_field(pos, t):
    x, y, z = pos
    u = 1   # Constant x-component
    v = 0   # No movement in Y direction
    w = 0   # No movement in Z direction
    return [u, v, w]

# Function to compute streamlines, clipped to stay within bounds
def compute_streamlines(starting_points, t_max=10, num_points=500):
    streamlines = []
    t = np.linspace(0, t_max, num_points)
    
    for start_point in starting_points:
        streamline = odeint(vector_field, start_point, t)
        # Clip streamline points to stay within plot boundaries (-6 to 6)
        streamline = np.clip(streamline, -6, 6)
        streamlines.append(streamline)
    
    return streamlines

# Define the grid size and create starting points
n = 5  # Reduced number of starting points
x = np.linspace(-5, 5, n)
y = np.linspace(-5, 5, n)
z = np.linspace(-5, 5, n)

# Create a 3D meshgrid for starting points
X, Y, Z = np.meshgrid(x, y, z)

# Flatten the grid to get a list of starting points
starting_points = np.array([X.ravel(), Y.ravel(), Z.ravel()]).T

# Compute streamlines
streamlines = compute_streamlines(starting_points)

# Create 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot streamlines (reduced density for better visualization)
for streamline in streamlines:
    ax.plot(streamline[:, 0], streamline[:, 1], streamline[:, 2], color='b')

# Set plot limits and labels (constrained to avoid going out of bounds)
ax.set_xlim([-6, 6])
ax.set_ylim([-6, 6])
ax.set_zlim([-6, 6])
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %%
# streamlines visualization of the 3d radial field

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.integrate import odeint

# Define the radial vector field
def radial_vector_field(pos, t):
    x, y, z = pos
    u = x  # X-component of the vector field
    v = y  # Y-component of the vector field
    w = z  # Z-component of the vector field
    return [u, v, w]

# Function to compute streamlines, clipped to stay within bounds
def compute_streamlines(starting_points, t_max=10, num_points=500):
    streamlines = []
    t = np.linspace(0, t_max, num_points)
    
    for start_point in starting_points:
        streamline = odeint(radial_vector_field, start_point, t)
        # Clip streamline points to stay within plot boundaries (-6 to 6)
        streamline = np.clip(streamline, -6, 6)
        streamlines.append(streamline)
    
    return streamlines

# Define the grid size and create starting points
n = 5  # Reduced number of starting points

x = np.linspace(-5, 5, n)
y = np.linspace(-5, 5, n)
z = np.linspace(-5, 5, n)

# Create a 3D meshgrid for starting points
X, Y, Z = np.meshgrid(x, y, z)

# Flatten the grid to get a list of starting points
starting_points = np.array([X.ravel(), Y.ravel(), Z.ravel()]).T

# Compute streamlines
streamlines = compute_streamlines(starting_points)

# Create 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot streamlines (reduced density for better visualization)
for streamline in streamlines:
    ax.plot(streamline[:, 0], streamline[:, 1], streamline[:, 2], color='b')

# Set plot limits and labels (constrained to avoid going out of bounds)
ax.set_xlim([-6, 6])
ax.set_ylim([-6, 6])
ax.set_zlim([-6, 6])

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
